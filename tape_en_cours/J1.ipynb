# %% [markdown]
# # Jour 1

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 12, 3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Matin
#
# * blabla
# * `import this`
# * utilisation de `ipython` à la place de `python`
# * installation de python
#     * notion de `PATH` / commande `where` qui permet de lister les chemins absolus des commandes
#     * notion d'environnement virtuel
# * environnements virtuels
#     * création (une seule fois) : `python -m venv NOM_DU_VENV`
#     * activation : `
